# %%
import pandas as pd
from bs4 import BeautifulSoup as bs
import requests

# %%
url = "https://www-fars.nhtsa.dot.gov/Main/index.aspx"
r = requests.get(url)

# %%
print(r)
# Out:
# <Response [200]>

# %%
soup = bs(r.text)
table = soup.find('table', {'class': 'datatable01'})
columns = []
data = []

# Get the headers
headers = table.find_all('th')
for header in headers:
    print(header)
    columns.append(header.get_text())

# Get the rows
rows = table.find_all('tr')
for row in rows:
    cells = row.find_all('td')
    row_data = []
    for cell in cells:
        row_data.append(cell.get_text())
    if row_data:
        data.append(row_data)

#df = pd.DataFrame(data, columns=columns)
headers
# Out:
# <th id="hdrCol0" scope="col"><a href="javascript:__doPostBack('ctl00$PageContent$ctlTblTyp11MnHome1$rptrTableType11$ctl00$lnkWHeader','')" id="ctl00_PageContent_ctlTblTyp11MnHome1_rptrTableType11_ctl00_lnkWHeader" onclick="javascript:window.open('../Common/FileVersions.html','', 'width=400,height=500,scrollbars=0,menubar=0');return false;"></a></th>
# <th id="hdrCol1" scope="col">2021 </th>
# <th id="hdrCol2" scope="col">2020 </th>
# <th id="hdrCol3" scope="col">2019 </th>
# <th id="hdrCol4" scope="col">2018 </th>
# <th id="hdrCol5" scope="col">2017 </th>
# <th id="hdrCol6" scope="col">2016 </th>
# <th id="hdrCol7" scope="col">2015 </th>
# <th id="hdrCol8" scope="col">2014 </th>
# <th id="hdrCol9" scope="col">2013 </th>
# <th id="hdrCol10" scope="col">2012 </th>
# <th id="hdrCol11" scope="col">2011 </th>
# <th id="hdrCol12" scope="col">2010 </th>
# <th id="hdrCol13" scope="col">2009 </th>
# <th id="hdrCol14" scope="col">2008 </th>
# <th id="hdrCol15" scope="col">2007 </th>
# ...

# %%
# Out:
# [                                                   0
#  0  New Vehicle Classification for 2020 and later ...,
#                                                     0  \
#  0  Did You Know?  View Archive  Large trucks acco...
#
#                                                     1
#  0  Did You Know?  View Archive  Large trucks acco...  ,
#      0                1   2   3   4   5   6
#  0 NaN  Skip Navigation NaN NaN NaN NaN NaN,
#                                                     0  \
#  0                                                NaN
#  1  Did You Know?  View Archive  Large trucks acco...
#
#                                                     1
#  0                                                NaN
#  1  Did You Know?  View Archive  Large trucks acco...  ,
#                                                     0
#  0  Did You Know?  View Archive  Large trucks acco...,
#                                                     0  \
# ...

# %%
as_df = pd.read_csv('./airline-safety.csv')

# %%
as_df
# Out:
#                        airline  avail_seat_km_per_week  incidents_85_99  \
# 0                   Aer Lingus            3.209067e+08                2
# 1                    Aeroflot*            1.197672e+09               76
# 2        Aerolineas Argentinas            3.858036e+08                6
# 3                  Aeromexico*            5.968718e+08                3
# 4                   Air Canada            1.865254e+09                2
# 5                   Air France            3.004003e+09               14
# 6                   Air India*            8.692536e+08                2
# 7             Air New Zealand*            7.101748e+08                3
# 8             Alaska Airlines*            9.653468e+08                5
# 9                     Alitalia            6.980125e+08                7
# 10          All Nippon Airways            1.841234e+09                3
# 11                   American*            5.228357e+09               21
# ...

# %%
as_df.sort_values(by='fatalities_00_14', ascending=False)
# Out:
#                        airline  avail_seat_km_per_week  incidents_85_99  \
# 56                         NaN                     NaN              402
# 34           Malaysia Airlines            1.039171e+09                3
# 11                   American*            5.228357e+09               21
# 5                   Air France            3.004003e+09               14
# 29               Kenya Airways            2.774148e+08                2
# 16              China Airlines            8.132165e+08               12
# 47                         TAM            1.509196e+09                8
# 6                   Air India*            8.692536e+08                2
# 25                    Gulf Air            3.013798e+08                1
# 39                        SAS*            6.829719e+08                5
# 51       United / Continental*            7.139291e+09               19
# 22          Ethiopian Airlines            4.885606e+08               25
# ...

# %%
as_df.columns
# Out:
# Index(['airline', 'avail_seat_km_per_week', 'incidents_85_99',
#        'fatal_accidents_85_99', 'fatalities_85_99', 'incidents_00_14',
#        'fatal_accidents_00_14', 'fatalities_00_14'],
#       dtype='object')
